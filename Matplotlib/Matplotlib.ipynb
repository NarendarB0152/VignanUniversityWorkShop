# %% [markdown]
# <a href="https://colab.research.google.com/github/NarendarB0152/VignanUniversityWorkShop/blob/main/Matplotlib/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,48,53,54,48,43]

# %%
plt.title('Weather')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.plot(x,y,color="green",linewidth=5,linestyle="dotted")

# %%
plt.plot(x,y,"b+--")

# %%
# Same effect as 'b+' format string
plt.plot(x,y,color='blue',marker='*',linestyle='',markersize=30)

# %%
plt.plot(x,y,'g<',alpha=0.5,markersize=30)

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avg")

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best')

# %% [markdown]
# # Bar chart

# %%
import numpy as np
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos=np.arange(len(company))

# %%
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue,label="Revenue")
plt.xticks(xpos,company)
plt.title("Us technology stocks")
plt.ylabel("Revenue")
plt.legend()

# %%
profit=[40,2,34,12]
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technolog Stocks')
plt.legend()

# %% [markdown]
# # histogram

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,rwidth=0.8,bins=4)
# Out:
# (array([7., 1., 2., 3.]),
#  array([ 77.  ,  95.25, 113.5 , 131.75, 150.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='g')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x7ba3b5639d30>])

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, orientation='horizontal')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
# Pie Chart

# %% [markdown]
# # Pie Chart

# %%
exp_vals=[1400,600,410,250]
exp_labels=["home rent","phone bill","car","other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ba3b5b9a000>,
#   <matplotlib.patches.Wedge at 0x7ba3b545df40>,
#   <matplotlib.patches.Wedge at 0x7ba3b596fcb0>,
#   <matplotlib.patches.Wedge at 0x7ba3b596e300>],
#  [Text(-0.09083739236204597, 1.0962429329983678, 'home rent'),
#   Text(-0.7059598634891525, -0.8435761205382578, 'phone bill'),
#   Text(0.523542023696162, -0.9674211851226577, 'car'),
#   Text(1.0523984773881274, -0.3200897449015684, 'other Utilities')])

# %%
plt.pie(exp_vals,labels=exp_labels,shadow=True)
plt.axis("equal")
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0.1,0.5])
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1, 2, 3, 4, 5, 6]
y = [5, 7, 4, 8, 6, 9]

plt.scatter(x, y)
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Scatter Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

data = [25, 30, 45, 50, 55, 60, 61, 70, 85, 90]

plt.boxplot(data)
plt.title("Box Plot")
plt.ylabel("Values")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

data = [[1, 0.8, 0.3],
        [0.8, 1, 0.5],
        [0.3, 0.5, 1]]

sns.heatmap(data, annot=True)
plt.title("Heatmap Example")
plt.show()
